# %%
import pandas as pd

# %%
df1=pd.read_csv("/content/drive/MyDrive/salaries data/Salaries.csv")
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (12) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df1.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year  Notes         Agency Status
# ...

# %%
df1.shape
# Out:
# (148654, 13)

# %%
df1.columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency',
#        'Status'],
#       dtype='object')

# %%
df1.columns.shape
# Out:
# (13,)

# %%
df1.index.shape
# Out:
# (148654,)

# %%
# Alternative
df1.shape[0]
# Out:
# 13

# %%
df1.shape[1]
# Out:
# 13

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148049 non-null  float64
#  4   OvertimePay       148654 non-null  float64
#  5   OtherPay          148654 non-null  float64
#  6   Benefits          112495 non-null  float64
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            38119 non-null   object
# dtypes: float64(7), int64(2), object(4)
# memory usage: 14.7+ MB

# %%
df1.isnull().sum()
# Out:
# Id                       0
# EmployeeName             0
# JobTitle                 0
# BasePay                605
# OvertimePay              0
# OtherPay                 0
# Benefits             36159
# TotalPay                 0
# TotalPayBenefits         0
# Year                     0
# Notes               148654
# Agency                   0
# Status              110535
# dtype: int64

# %%
list1=['Id', 'Notes', 'Agency', 'Status']
df1.drop(list1, axis=1)
# Out:
#              EmployeeName                                        JobTitle  \
# 0          NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1            GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2          ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3       CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4         PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# ...                   ...                                             ...
# 148649      Roy I Tillery                                       Custodian
# 148650                  0                                               0
# 148651                  0                                               0
# 148652                  0                                               0
# 148653          Joe Lopez                      Counselor, Log Cabin Ranch
#
#           BasePay  OvertimePay   OtherPay  Benefits   TotalPay  \
# ...

# %%
df1.describe()
# Out:
#                   Id        BasePay    OvertimePay       OtherPay  \
# count  148654.000000  148049.000000  148654.000000  148654.000000
# mean    74327.500000   66323.656854    5065.923568    3648.669115
# std     42912.857795   42765.447379   11454.256594    8056.515703
# min         1.000000    -166.010000      -0.010000   -7058.590000
# 25%     37164.250000   33583.520000       0.000000       0.000000
# 50%     74327.500000   65006.930000       0.000000     811.170000
# 75%    111490.750000   94691.050000    4657.632500    4235.907500
# max    148654.000000  319275.010000  245131.880000  400184.250000
#
#             Benefits       TotalPay  TotalPayBenefits           Year  Notes
# count  112495.000000  148654.000000     148654.000000  148654.000000    0.0
# mean    25007.003942   74768.321972      93692.554811    2012.522643    NaN
# std     15402.663885   50517.005274      62793.533483       1.117538    NaN
# ...

# %% [markdown]
# Find the number of occurance of employees name

# %%
df1.columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency',
#        'Status'],
#       dtype='object')

# %%
df1['EmployeeName'].value_counts().head()
# Out:
# Kevin Lee       13
# Steven Lee      11
# William Wong    11
# Richard Lee     11
# Stanley Lee      9
# Name: EmployeeName, dtype: int64

# %% [markdown]
# Find the number of unique job titles

# %%
df1['JobTitle'].nunique()
# Out:
# 2143

# %%
# by using loop
count=0
titles=[]
for i in range(0,len(df1['JobTitle'])):
    if df1['JobTitle'][i] not in titles:
        titles.append(df1['JobTitle'][i])
        count=count+1
print(count)
print(titles)
# Out:
# 2143
# ...

# %% [markdown]
# Total number of job titles contain captain

# %%
df1.columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency',
#        'Status'],
#       dtype='object')

# %%
len(df1[df1['JobTitle'].str.contains("Captain", case=False)])
# Out:
# 552

# %% [markdown]
# Display all the employee names from fire department

# %%
df1.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year  Notes         Agency Status
# ...

# %%
df1[df1['JobTitle'].str.contains("(Fire department)", case=False)].count()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   """Entry point for launching an IPython kernel.
# Id                  226
# EmployeeName        226
# JobTitle            226
# BasePay             225
# OvertimePay         226
# OtherPay            226
# Benefits              4
# TotalPay            226
# TotalPayBenefits    226
# Year                226
# Notes                 0
# Agency              226
# Status                1
# dtype: int64

# %%
df1['BasePay'].str.contains('Not Provided')
# Out:
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
#           ...
# 148649    False
# 148650     True
# 148651     True
# 148652     True
# 148653    False
# Name: BasePay, Length: 148654, dtype: object

# %%
df1['BasePay'].min
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.min of 0            167411.18
# 1            155966.02
# 2            212739.13
# 3              77916.0
# 4             134401.6
#               ...
# 148649            0.00
# 148650    Not Provided
# 148651    Not Provided
# 148652    Not Provided
# 148653            0.00
# Name: BasePay, Length: 148654, dtype: object>

# %% [markdown]
# Find the error basepay which are in negative

# %%
list2=[]
count1=0
for i in range(0,len(df1['BasePay'])):
    if df1['BasePay'][i]<0:
        list2.append(df1['BasePay'][i])
        count1+=1
print(list2)
print(count1)
# Out:
# [-166.01, -121.63, -109.22, -106.6, -101.88, -93.14, -87.38, -75.67, -59.59, -30.58, -9.5]
# 11

# %% [markdown]
# Find the corrected column of basepay

# %%
list3=[]
count2=0
for i in range(0,len(df1['BasePay'])):
    if df1['BasePay'][i]>20000:
        list3.append(df1['BasePay'][i])
        count2+=1
print(list3)
print(count2)
# Out:
# [167411.18, 155966.02, 212739.13, 77916.0, 134401.6, 118602.0, 92492.01, 256576.96, 176932.64, 285262.0, 194999.39, 99722.0, 294580.02, 271329.03, 174872.64, 198778.01, 268604.57, 140546.87, 168692.63, 257510.59, 257510.48, 257510.44, 140546.88, 168692.63, 140546.86, 256470.41, 92080.8, 168692.59, 261717.6, 246225.6, 234325.02, 254027.63, 248895.7, 104861.39, 177781.25, 101953.2, 245124.44, 110661.2, 132202.26, 147158.85, 168692.66, 168692.63, 218930.76, 123013.02, 196081.86, 249375.02, 168692.64, 248895.77, 233867.6, 137729.92, 168692.59, 246305.62, 140546.87, 140546.88, 140546.89, 226206.8, 240731.93, 217410.8, 115381.02, 214745.44, 123105.0, 102571.24, 140546.86, 168692.62, 148970.43, 185369.69, 177914.76, 139167.39, 122974.0, 115455.44, 220983.12, 92782.61, 95770.8, 233357.28, 130457.88, 85578.61, 174872.64, 73754.05, 140546.88, 168692.62, 172529.08, 122272.69, 168692.62, 230827.12, 217410.8, 122404.98, 150464.82, 96814.36, 88062.0, 138878.82, 188842.37, 102722.4, 149362.84, 2159
# ...

# %%
df1.isnull().sum(axis=1)
# Out:
# 0         3
# 1         3
# 2         3
# 3         3
# 4         3
#          ..
# 148649    1
# 148650    2
# 148651    2
# 148652    2
# 148653    1
# Length: 148654, dtype: int64

# %%
# drop rows having 5 or more missing values
df1.drop(df1[df1.isnull().sum(axis=1)==5].index, axis=0, inplace=True)

# %%
df1.isnull().sum(axis=1)
# Out:
# 0         3
# 1         3
# 2         3
# 3         3
# 4         3
#          ..
# 148649    1
# 148650    2
# 148651    2
# 148652    2
# 148653    1
# Length: 148654, dtype: int64

# %% [markdown]
# Find job title of Albert Pardini

# %%
df1.columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency',
#        'Status'],
#       dtype='object')

# %%
df1[df1['EmployeeName']=='ALBERT PARDINI']['JobTitle']
# Out:
# 2    CAPTAIN III (POLICE DEPARTMENT)
# Name: JobTitle, dtype: object

# %%
df1[df1['EmployeeName']=='ALBERT PARDINI']['TotalPayBenefits']
# Out:
# 2    335279.91
# Name: TotalPayBenefits, dtype: float64

# %% [markdown]
# Display the name of the person having the highest base pay

# %%
df1.columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency',
#        'Status'],
#       dtype='object')

# %%
df1.BasePay.unique()
# Out:
# array([167411.18, 155966.02, 212739.13, ..., '6.04', '15.50',
#        'Not Provided'], dtype=object)

# %%
df1.BasePay.max()
# Out:
# 319275.01

# %%
df1[df1['BasePay']==df1['BasePay'].max()]['EmployeeName']
# Out:
# 72925    Gregory P Suhr
# Name: EmployeeName, dtype: object

# %% [markdown]
# Find average base pay of all employee per year

# %%
df1.columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency',
#        'Status'],
#       dtype='object')

# %%
df1.groupby('Year').mean()['BasePay']
# Out:
# Year
# 2011    63595.956517
# 2012    65436.406857
# 2013    69630.030216
# 2014    66557.437750
# Name: BasePay, dtype: float64

# %% [markdown]
# Find average basepay of all employee per job title

# %%
df1.groupby('JobTitle').mean()['BasePay']
# Out:
# JobTitle
# 0                                                     0.000000
# ACCOUNT CLERK                                     43300.806506
# ACCOUNTANT                                        46643.172000
# ACCOUNTANT INTERN                                 28732.663958
# ACPO,JuvP, Juv Prob (SFERS)                       62290.780000
#                                                       ...
# X-RAY LABORATORY AIDE                             47664.773077
# X-Ray Laboratory Aide                             46086.387100
# YOUTH COMMISSION ADVISOR, BOARD OF SUPERVISORS    52609.910000
# Youth Comm Advisor                                39077.957500
# ZOO CURATOR                                       43148.000000
# Name: BasePay, Length: 2159, dtype: float64

# %% [markdown]
# Find average Basepay of Employee having job title ACCOUNTANT

# %%
df1[df1['JobTitle']=='ACCOUNTANT']['BasePay'].mean()
# Out:
# 46643.172

# %% [markdown]
# 5 most common jobs

# %%
df1['JobTitle'].value_counts().head()
# Out:
# Transit Operator                7036
# Special Nurse                   4389
# Registered Nurse                3736
# Public Svc Aide-Public Works    2518
# Police Officer 3                2421
# Name: JobTitle, dtype: int64
